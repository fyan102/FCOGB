# %%
(delta_avg_o-delta_avg_x).clip(-1, 1)
# Out:
# array([-3.12385340e-02, -8.45544900e-02, -9.43388360e-02, -4.05516010e-02,
#        -1.09743150e-01, -8.00544200e-03, -8.12574200e-03, -3.25973000e-04,
#        -5.72331080e-02, -3.96310300e-03, -5.39025100e-03, -1.21482130e-02,
#         8.49369500e-03, -2.63530510e-02, -4.57809800e-03, -1.61465510e-02,
#        -2.42786700e-03, -1.25417870e-02, -1.61227700e-03, -3.39158000e-04,
#        -3.25005730e-02, -7.45992600e-03, -6.96432200e-03, -2.82801200e-03,
#        -1.16969400e-03, -2.90314100e-03, -8.82152900e-03, -2.17500000e-06,
#        -9.65840000e-05, -4.00657761e-01, -1.00000000e+00, -1.05788170e-02,
#        -1.00000000e+00, -1.13421354e-01])

# %%
(delta_avg_o - delta_avg_s).mean()
# Out:
# -0.014747558852941175

# %%
delta_avg_x
# Out:
# array([6.89503223e-01, 7.40291587e-01, 4.11660920e-01, 3.98372201e-01,
#        3.50464240e-01, 2.19943026e-01, 7.03580335e-01, 9.97048864e-01,
#        3.94431787e-01, 8.40668520e-01, 7.36140861e-01, 6.19783064e-01,
#        3.84229790e-01, 1.92359784e-01, 8.44407700e-02, 1.64835258e-01,
#        5.96124080e-02, 3.93691309e-01, 2.26818851e-01, 3.76616400e-02,
#        2.23785523e-01, 1.59972850e-01, 1.10296537e-01, 4.93835630e-02,
#        4.07667260e-02, 1.65500991e-01, 5.61849454e-01, 9.53722426e-01,
#        4.81125600e-02, 5.78550417e-01, 4.26570929e+00, 4.11546037e-01,
#        1.45244268e+02, 2.55499362e-01])

# %%
delta = 0.05
noh = 20
delta_corr = delta/noh
margins = [0, 0.001, 0.01]

# %%
delta_corr
# Out:
# 0.0025

# %%
tests = [['R_O_avg < R_S_avg', delta_avg_o, delta_avg_s],
         ['R_O_avg < R_G_avg', delta_avg_o, delta_avg_g],
         ['R_O_avg < R_X_avg', delta_avg_o, delta_avg_x],
         ['R_O_bc < R_S_bc', delta_bc_so_o, delta_bc_so_s],
         ['R_O_bc < R_G_bc', delta_bc_go_o, delta_bc_go_g],
         ['R_O_bc < R_X_bc', delta_bc_xo_o, delta_bc_xo_x],
         ['R_O_wc > R_S_wc', delta_wc_so_o, delta_wc_so_s],
         ['R_O_wc > R_G_wc', delta_wc_go_o, delta_wc_go_g],
         ['R_O_wc > R_X_wc', delta_wc_xo_o, delta_wc_xo_x],
         ['R_O_avg_test < R_S_avg_test', delta_avg_o_test, delta_avg_s_test],
         ['R_O_avg_test < R_G_avg_test', delta_avg_o_test, delta_avg_g_test],
         ['R_O_avg_test < R_X_avg_test', delta_avg_o_test, delta_avg_x_test],
         ['R_O_bc_test < R_S_bc_test', delta_bc_so_o_test, delta_bc_so_s_test],
         ['R_O_bc_test < R_G_bc_test', delta_bc_go_o_test, delta_bc_go_g_test],
         ['R_O_bc_test < R_X_bc_test', delta_bc_xo_o_test, delta_bc_xo_x_test],
         ['R_O_wc_test > R_S_wc_test', delta_wc_so_o_test, delta_wc_so_s_test],
         ['R_O_wc_test > R_G_wc_test', delta_wc_go_o_test, delta_wc_go_g_test],
         ['R_O_wc_test > R_X_wc_test', delta_wc_xo_o_test, delta_wc_xo_x_test],]

for n, a, b in tests:
    print(n)
    alter = 'greater' if 'wc' in n else 'less'
    for m in margins:
        print('margin', m, end=': \t')
        if 'X' in n:
            a = a[:-5]
            b = b[:-5] # include the hypothesis of not considering xgb for poisson
        if not 'wc' in n:
            avg_so=ttest_rel((np.array(a)+m).clip(0, 1), b.clip(0, 1), alternative=alter)
        else:
            avg_so=ttest_rel((np.array(a)).clip(0, 1), (b+m).clip(0, 1), alternative=alter)
        print(avg_so.pvalue, '\t' ,avg_so.pvalue <= delta_corr)
    print()
# Out:
# R_O_avg < R_S_avg
# margin 0: 	0.0011204382370852278 	 True
# margin 0.001: 	0.0020274230700518237 	 True
# margin 0.01: 	0.13645462102405062 	 False
#
# R_O_avg < R_G_avg
# margin 0: 	2.387458753321433e-05 	 True
# margin 0.001: 	7.815682508604418e-05 	 True
# margin 0.01: 	0.2504043692906664 	 False
#
# R_O_avg < R_X_avg
# margin 0: 	0.0007169927902872124 	 True
# margin 0.001: 	0.0011649069913582167 	 True
# margin 0.01: 	0.02160009880836886 	 False
#
# R_O_bc < R_S_bc
# margin 0: 	6.090891350147956e-07 	 True
# margin 0.001: 	7.331299472631623e-07 	 True
# margin 0.01: 	3.584311804164077e-06 	 True
#
# R_O_bc < R_G_bc
# margin 0: 	3.688480825357134e-06 	 True
# margin 0.001: 	4.6801781400428425e-06 	 True
# margin 0.01: 	3.582362894005683e-05 	 True
#
# R_O_bc < R_X_bc
# margin 0: 	4.337707297775962e-05 	 True
# margin 0.001: 	6.077116901734108e-05 	 True
# margin 0.01: 	0.0005551219671407897 	 True
#
# R_O_wc > R_S_wc
# margin 0: 	0.001766919889708946 	 True
# ...

# %%
for n, a, b in tests:
    print(n, end=': ')
    if not 'wc' in n:
        print((a+0.1<b).sum()/34)
    else:
        print((a>b+0.1).sum()/34)
# Out:
# R_O_avg < R_S_avg: 0.0
# R_O_avg < R_G_avg: 0.0
# R_O_avg < R_X_avg: 0.14705882352941177
# R_O_bc < R_S_bc: 0.4411764705882353
# R_O_bc < R_G_bc: 0.17647058823529413
# R_O_bc < R_X_bc: 0.29411764705882354
# R_O_wc > R_S_wc: 0.08823529411764706
# R_O_wc > R_G_wc: 0.058823529411764705
# R_O_wc > R_X_wc: 0.0
# R_O_avg_test < R_S_avg_test: 0.0
# R_O_avg_test < R_G_avg_test: 0.0
# R_O_avg_test < R_X_avg_test: 0.11764705882352941
# R_O_bc_test < R_S_bc_test: 0.11764705882352941
# R_O_bc_test < R_G_bc_test: 0.23529411764705882
# R_O_bc_test < R_X_bc_test: 0.029411764705882353
# R_O_wc_test > R_S_wc_test: 0.11764705882352941
# R_O_wc_test > R_G_wc_test: 0.058823529411764705
# R_O_wc_test > R_X_wc_test: 0.029411764705882353
