#        1.72430277e-01, 1.11598513e-01, 6.58109790e-02, 1.76244220e-02,
#        1.48282250e-02, 1.12156155e-01, 5.23981386e-01, 9.52547045e-01,
#        2.37183670e-02, 2.06202297e-01, 1.59668077e+00, 2.04562684e-01,
#        4.36732280e+01, 8.88379920e-02])

# %%
delta = 0.05
noh = 6
delta_corr = delta/noh
margins = [0, 0.001, 0.01]

# %%
delta_corr
# Out:
# 0.008333333333333333

# %%
tests = [['R_O_avg < R_S_avg', delta_avg_o, delta_avg_s],
         ['R_O_avg < R_G_avg', delta_avg_o, delta_avg_g],
         ['R_O_avg < R_X_avg', delta_avg_o, delta_avg_x],
         ['R_O_avg < R_SI_avg', avg_o_no_poi, avg_sirus],
         ['R_O_avg_test < R_S_avg_test', delta_avg_o_test, delta_avg_s_test],
         ['R_O_avg_test < R_G_avg_test', delta_avg_o_test, delta_avg_g_test],
         ['R_O_avg_test < R_X_avg_test', delta_avg_o_test, delta_avg_x_test],
         ['R_O_avg_test < R_SI_avg_test', avg_o_no_poi_test, avg_sirus_test],
        ]

for n, a, b in tests:
    print(n)
    alter = 'greater' if 'wc' in n else 'less'
    for m in margins:
        print('margin', m, end=': \t')
        if 'X' in n or 'SI' in n:
            a = a[:-5]
            b = b[:-5] # include the hypothesis of not considering xgb for poisson
        if not 'wc' in n:
            avg_so=ttest_rel((np.array(a)+m).clip(0, 1), b.clip(0, 1), alternative=alter)
        else:
            avg_so=ttest_rel((np.array(a)).clip(0, 1), (b+m).clip(0, 1), alternative=alter)
        print(avg_so.pvalue, '\t' ,avg_so.pvalue <= delta_corr)
    print()
# Out:
# R_O_avg < R_S_avg
# margin 0: 	0.00501235442450724 	 True
# margin 0.001: 	0.006598613906516949 	 True
# margin 0.01: 	0.05675480682042396 	 False
#
# R_O_avg < R_G_avg
# margin 0: 	0.0015121667876592886 	 True
# margin 0.001: 	0.002684310741489743 	 True
# margin 0.01: 	0.15457045490794208 	 False
#
# R_O_avg < R_X_avg
# margin 0: 	0.002191801236607734 	 True
# margin 0.001: 	0.0036267586319668125 	 True
# margin 0.01: 	0.09079833769620653 	 False
#
# R_O_avg < R_SI_avg
# margin 0: 	0.0007799986170346251 	 True
# margin 0.001: 	0.001529108024617253 	 True
# margin 0.01: 	0.002216924323161314 	 True
#
# R_O_avg_test < R_S_avg_test
# margin 0: 	0.8439030284871499 	 False
# margin 0.001: 	0.8522311886953832 	 False
# margin 0.01: 	0.9139125910205056 	 False
#
# R_O_avg_test < R_G_avg_test
# margin 0: 	0.538850842814609 	 False
# margin 0.001: 	0.5609858573194676 	 False
# margin 0.01: 	0.7460143917950631 	 False
#
# R_O_avg_test < R_X_avg_test
# margin 0: 	0.16071242895179247 	 False
# ...

# %%
for n, a, b in tests:
    print(n, end=': ')
    print((a<b).sum()/34)
# Out:
# R_O_avg < R_S_avg: 0.8823529411764706
# R_O_avg < R_G_avg: 0.9411764705882353
# R_O_avg < R_X_avg: 0.9411764705882353
# R_O_avg < R_SI_avg: 0.7058823529411765
# R_O_avg_test < R_S_avg_test: 0.29411764705882354
# R_O_avg_test < R_G_avg_test: 0.6176470588235294
# R_O_avg_test < R_X_avg_test: 0.7352941176470589
# R_O_avg_test < R_SI_avg_test: 0.5588235294117647

# %%
avg_tr=np.array([0.568865752,0.457810885,0.128836172,0.19383232,0.082599782,
                 0.532857527,0.651751785,0.99567228542,0.168794313,0.661603185,
                 0.687111702,0.569961916,0.9208206931,0.105138322,0.053432199,
                 0.056563666,0.028672963,0.31570994,0.2181765163,0.013615857,
                 0.172430277,0.111598513,0.065810979,0.017554635,0.014828225,
                 0.111291234,0.523846237,0.9890688091,0.023718367,0.087296239,
                 0.299225932,0.204562684,0.091539988,0.063018097])
avg_te=np.array([0.692026937,0.502284766,0.360026358,0.233647442,0.33326114,0.604575482,0.640479692,0.555065587,0.167561267,0.893281429,0.671028629,0.582769932,0.21541071,0.100195431,0.059925742,0.052252401,0.032560472,0.317470725,0.170961203,0.01486658,0.128138638,0.133644549,0.064556336,0.021954921,0.015832492,0.101529706,0.43461674,0.716642677,0.024324237,0.086882335,0.417240909,0.355625103,0.207133702,0.095283483])

delta_avg_o
# Out:
# array([0.54519327, 0.33926502, 0.1279145 , 0.184576  , 0.08328485,
#        0.5317423 , 0.64492366, 0.99529462, 0.13808868, 0.6382302 ,
#        0.68415786, 0.56029797, 0.29743727, 0.09182342, 0.05065791,
#        0.05869906, 0.02725618, 0.30339624, 0.20085312, 0.0135143 ,
#        0.14770325, 0.10579284, 0.06192301, 0.01618661, 0.01431088,
#        0.11102164, 0.52033995, 0.95254639, 0.02346399, 0.08419309,
#        0.28966475, 0.19170595, 0.07337253, 0.04856703])

# %%
delta = 0.05
noh = 1
delta_corr = delta/noh
margins = [0, 0.001, 0.01]

# %%
delta_corr
# Out:
# 0.05

# %%
tests = [['R_O_avg < R_tr_avg', delta_avg_o, avg_tr],
#          ['R_O_avg_te < R_te_avg', delta_avg_o_test, avg_te],
        ]

for n, a, b in tests:
    print(n)
    alter = 'greater' if 'wc' in n else 'less'
    for m in margins:
        print('margin', m, end=': \t')
        if not 'wc' in n:
            avg_so=ttest_rel((np.array(a)+m).clip(0, 1), b.clip(0, 1), alternative=alter)
        else:
            avg_so=ttest_rel((np.array(a)).clip(0, 1), (b+m).clip(0, 1), alternative=alter)
        print(avg_so.pvalue, '\t' ,avg_so.pvalue <= delta_corr)
    print()
# Out:
# R_O_avg < R_tr_avg
# margin 0: 	5.450947134132011e-17 	 True
# margin 0.001: 	5.672673092219087e-17 	 True
# margin 0.01: 	7.733768020462767e-17 	 True
